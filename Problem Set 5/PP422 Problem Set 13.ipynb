# %% [markdown]
# # Instructions
#
# 1. Download the provided jupyter notebook file to your computer.
# 2. Write all your answers and code into this notebook file.
# 3. When your work is completed, export your notebook to an HTML file.
# 4. Submit your HTML file and a copy of the notebook to the assignment page on Moodle.

# %% [markdown]
# ## Identification
#
# ### Your Information
#
# Your Last Name:
#
# Your First Name:
#
#
# ### Group Members (list any classmates you worked with on this problem set)
#
# Your Group Members:

# %% [markdown]
# # Textbook Reading

# %% [markdown]
# The textbook readings for this week develop the theory of PCA in more detail and also introduce clustering methods.
#
# 1. ISLP - Chapter 12.You should read section 12.1 which provides a general overview of the unsupervised learning problem. Sections 12.2 presents more of the underlying maths and theory of PCA, while Section 12.3 discussions an application to missing data. You may skim these sections if you find them interesting, but the technical detail will be outside the scope of our course. You should read section 12.4 in its entirety.
# 2. Géron - Chapter 9. This chapter covers a wide range of unsupervised learning techniques. We will focus on a subst of the algorithms presented in the K-Means section. You may also wish to skim the section on DBSCAN, which is a useful algorithm for non-spherical clusters.

# %% [markdown]
# # Additional Reading - Applying AI to Rebuild Middle Class Jobs

# %% [markdown]
# Read the additional provided NBER Working Paper from David Autor - "Applying AI to Rebuild Middle Class Jobs". After reading the article, answer the following questions.

# %% [markdown]
# ## Comparison to Acemoglu and Johnson Piece from Last Week

# %% [markdown]
# Both this piece and the Acemoglu and Johnson reading from last week evaluate the expected potential impact of AI on job availability and the potential for worker displacement. In what ways are the arguments of these articles similar? In what ways are they different?

# %% [markdown]
# _Your answer here:_

# %% [markdown]
# ## The Role of Demographic Shifts

# %% [markdown]
# Autor often talks about the interaction between the growth in AI and demographic changes. Explain what the discussed demographic changes are and why they are important in this evaluation.

# %% [markdown]
# _Your answer here:_

# %% [markdown]
# ## AI as an Inversion Technology

# %% [markdown]
# Autor discusses the current development of AI as an "inversion technology" relative to pre-AI computing. Explain what is meant by this and why this distinction is important for the paper's argument.

# %% [markdown]
# _Your answer here:_

# %% [markdown]
# # Additional OPTIONAL Reading - Efficiency of the EU regulation on greenhouse gas emissions in Italy

# %% [markdown]
# The problem set folder also provided the following additional reading:
#
# Arbolino, Roberta, et al. "Efficiency of the EU regulation on greenhouse gas emissions in Italy: The hierarchical cluster analysis approach." Ecological Indicators 81 (2017): 115-123.
#
# In this article the authors use a mix of PCA and hierarchical clustering to analyze the degree to which EU level regulatory decisions are implemented locally. As you read the article, think about how both clusters are identified but also how the authors evaluate and contextualize the identified clusters ex-post.

# %% [markdown]
# # Clustering on OECD Dataset

# %% [markdown]
# The provided `oecd_regional_wellbeing.csv` contains data from the OECD on Regional Well-Being measures. The full documentation for this data is available at this [link](https://www.oecdregionalwellbeing.org/).
#
# The full dataset includes information by sub-national regions, but the provided data only contains information aggregated to the country-level.
#
# The goal of this problem is to allow you to practice clustering techniques on this data to see if we can arrive at measures of which countries are similar / dissimilar on these measure.
#
# I have provided a copy of the data to you which mirrors what you would download from the OECD website and I have not in general cleaned the data in any special way. You may need to clean the data and decide how you want to handle any missing values.
#
# Note: Throughout this problem you may use `random_state=0` to make your code replicable.

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans

# Plotting
# from lets_plot import *
# LetsPlot.setup_html()

# Additional packages for later interactive displays
from ipywidgets import interact, IntSlider, Dropdown, fixed

# %%
oecd = pd.read_csv('oecd_regional_wellbeing.csv', encoding='latin-1')
oecd
# Out:
#             country countrycode Disposable income per capita  Employment rate  \
# 0         Australia         AUS                       39 872             76.3
# 1           Austria         AUT                       37 640             75.5
# 2           Belgium         BEL                       35 487             62.8
# 3            Canada         CAN                       32 387             72.2
# 4             Chile         CHL                        8 261             62.9
# 5          Colombia         COL                          NaN             59.8
# 6        Costa Rica         CRI                       10 470             71.5
# 7           Czechia         CZE                       26 092             75.1
# 8           Denmark         DNK                       27 796             76.8
# 9           Estonia         EST                       17 711             74.4
# 10          Finland         FIN                       28 154             72.2
# 11           France         FRA                       30 656             65.0
# 12          Germany         DEU                       35 532             76.2
# 13           Greece         GRC                       20 931             70.9
# 14          Hungary         HUN                       21 024             73.8
# 15          Iceland         ISL                       30 704             84.9
# 16          Ireland         IRL                       29 853             75.1
# 17           Israel         ISR                       15 120             69.7
# 18            Italy         ITA                       31 920             61.9
# 19            Japan         JPN                       22 891             73.3
# 20            Korea         KOR                       25 303             62.0
# 21           Latvia         LVA                       15 293             70.1
# 22        Lithuania         LTU                       17 929             72.5
# 23       Luxembourg         LUX                       45 344             68.2
# 24           Mexico         MEX                        8 358             63.9
# 25      Netherlands         NLD                       31 827             84.3
# 26      New Zealand         NZL                       25 124             78.4
# 27           Norway         NOR                       32 368             77.4
# 28           Poland         POL                       24 597             76.6
# 29         Portugal         PRT                       26 467             72.6
# 30  Slovak Republic         SVK                       20 282             76.0
# 31         Slovenia         SVN                       27 250             73.1
# 32            Spain         ESP                       26 156             61.3
# 33           Sweden         SWE                       30 943             77.4
# 34      Switzerland         CHE                       64 469             83.9
# 35          Türkiye         TUR                          NaN             70.9
# 36   United Kingdom         GBR                       33 222             78.5
# 37    United States         USA                       59 961             76.6
# 38         Bulgaria         BGR                       17 805             70.8
# 39          Croatia         HRV                       20 013             68.2
# 40          Romania         ROU                       19 865             63.8
#
#     Unemployment rate  Homicide rate  Life expectancy  \
# 0                 4.1            0.9             83.0
# 1                 4.8            0.7             81.9
# 2                 5.8            1.4             82.3
# 3                 6.1            1.9             81.3
# 4                 8.7            4.5             81.0
# 5                11.5           25.5             76.8
# 6                 7.3           17.2             80.9
# 7                 2.3            1.5             79.9
# 8                 5.3            0.8             81.8
# 9                 7.9            1.7             79.0
# 10                9.4            1.1             81.6
# 11                7.6            1.2             83.0
# 12                8.2            0.8             81.1
# 13               12.9            0.7             81.8
# 14                4.4            0.7             76.5
# 15                3.6            1.3             82.4
# 16                4.5            0.7             82.9
# 17                3.7            1.5             82.6
# 18                7.5            0.6             83.4
# 19                2.7            0.7             84.7
# 20                2.7            1.1             83.5
# 21                8.4            4.3             75.5
# 22                6.8            2.6             77.4
# 23                6.6            1.4             83.4
# 24                2.7           24.2             75.5
# 25                3.9            0.6             81.9
# 26                3.6            0.9             81.8
# 27                3.7            0.7             83.1
# 28                3.1            1.4             78.4
# 29                6.2            0.7             81.2
# 30                5.4            1.1             78.2
# 31                3.7            0.3             82.0
# 32               12.7            0.7             83.8
# 33                8.5            1.1             83.4
# 34                4.2            0.6             84.3
# 35               12.1            2.5             77.3
# 36                3.6            0.9             80.7
# 37                3.7            5.9             77.0
# 38                4.5            1.1             75.8
# 39                5.1            0.7             78.6
# 40                5.7            0.7             76.4
#
#     Population with at least secondary education  Number of rooms per capita  \
# 0                                           15.3                         2.3
# 1                                           13.8                         1.8
# 2                                           17.2                         2.1
# 3                                            6.9                         2.5
# 4                                           17.6                         1.3
# 5                                           36.8                         1.0
# 6                                           58.6                         1.1
# 7                                            5.7                         1.5
# 8                                           16.4                         1.9
# 9                                           11.2                         1.6
# 10                                          11.1                         1.8
# 11                                          16.1                         1.8
# 12                                          16.2                         1.8
# 13                                          17.9                         1.3
# 14                                          11.9                         1.6
# 15                                          17.5                         1.5
# 16                                          10.6                         2.0
# 17                                          12.4                         1.2
# 18                                          33.3                         1.5
# 19                                           5.4                         1.8
# 20                                           6.4                         1.6
# 21                                           9.1                         1.2
# 22                                           5.6                         1.6
# 23                                          17.6                         2.0
# 24                                          56.1                         1.5
# 25                                          19.2                         2.1
# 26                                          19.1                         2.4
# 27                                          16.3                         2.3
# 28                                           5.2                         1.4
# 29                                          38.5                         2.0
# 30                                           6.1                         1.1
# 31                                          11.0                         1.6
# 32                                          35.1                         2.0
# 33                                          11.3                         1.8
# 34                                          13.8                         1.8
# 35                                          52.4                         1.5
# 36                                          17.8                         2.0
# 37                                           9.7                         2.4
# 38                                          13.1                         1.3
# 39                                           9.7                         1.2
# 40                                          19.8                         1.1
#
#     Mortality rate  Voter turnout  Households broadband access  \
# 0              3.0           89.8                         86.1
# 1              8.6           75.6                         91.0
# 2              8.6           90.7                         94.6
# 3              6.3           62.2                         93.3
# 4              9.9           46.7                         75.2
# 5              9.3           60.4                         48.4
# 6              6.8           60.7                         80.1
# 7             10.2           65.4                         92.8
# 8              8.9           84.2                         92.5
# 9             10.3           63.5                         90.9
# 10             9.0           66.8                         95.5
# 11             8.0           77.8                         88.1
# 12            13.4           82.5                         88.8
# 13             9.1           53.7                         85.0
# 14            12.8           69.7                         94.8
# 15             8.4           66.9                         94.9
# 16             8.2           59.7                         93.5
# 17             7.5           68.5                         74.3
# 18             7.9           63.9                         84.1
# 19             7.2           56.0                         71.7
# 20             6.8           66.2                         99.9
# 21            12.7           59.4                         94.3
# 22            11.4           52.2                         90.4
# 23             7.9           87.2                         97.4
# 24            11.8           61.0                         75.6
# 25             8.9           81.6                         98.6
# 26             8.4           78.2                          NaN
# 27             8.1           77.1                         98.6
# 28            11.1           74.4                         95.0
# 29             8.4           59.8                         87.0
# 30            11.2           68.5                         90.5
# 31             8.7           53.6                         94.0
# 32             7.6           66.6                         96.8
# 33             7.9           87.1                        100.0
# 34             7.3           45.1                         98.1
# 35            11.2           88.9                         96.4
# 36             9.2           60.3                         99.8
# 37            10.0           65.3                         86.4
# 38            13.2           33.0                         83.5
# 39            11.3            NaN                         86.1
# 40            12.7           31.9                         88.2
#
#     Air quality (PM2.5)  Life satisfaction  \
# 0                   8.5                7.1
# 1                  11.1                7.0
# 2                  11.8                6.9
# 3                  12.7                7.0
# 4                  23.1                6.2
# 5                  13.5                5.8
# 6                   8.7                6.8
# 7                  13.0                6.8
# 8                   9.2                7.6
# 9                   9.1                6.4
# 10                  7.1                7.8
# 11                 10.7                6.7
# 12                 11.6                6.9
# 13                 11.1                5.9
# 14                 12.5                6.1
# 15                  6.5                NaN
# 16                  7.5                7.0
# 17                 20.6                7.3
# 18                 15.8                6.4
# 19                 17.2                6.0
# 20                 30.1                6.0
# 21                 10.4                6.2
# 22                  9.8                6.6
# 23                 10.5                7.2
# 24                 14.6                6.5
# 25                 12.1                7.4
# 26                  6.7                7.1
# 27                  6.8                7.4
# 28                 13.5                6.3
# 29                 10.5                6.0
# 30                 10.9                6.3
# 31                 13.5                6.7
# 32                  9.7                6.4
# 33                  6.8                7.3
# 34                 12.5                7.3
# 35                 14.5                4.9
# 36                  9.2                6.8
# 37                 12.7                6.8
# 38                  9.6                5.4
# 39                 12.4                6.0
# 40                 10.7                6.5
#
#     Satisfaction with housing affordability  Internet speed  \
# 0                                      41.6           -44.8
# 1                                      59.9           -42.5
# 2                                      59.3           -16.3
# 3                                      38.8            22.4
# 4                                      28.7            49.4
# 5                                      46.6           -18.9
# 6                                      55.0           -41.0
# 7                                      50.7           -41.9
# 8                                      71.3             7.6
# 9                                      62.8           -46.7
# 10                                     75.2           -13.1
# 11                                     47.9            46.3
# 12                                     55.8           -34.9
# 13                                     40.4           -56.2
# 14                                     44.8             3.9
# 15                                      NaN            33.5
# 16                                     42.5            -9.2
# 17                                     29.7            27.7
# 18                                     56.3            -9.0
# 19                                     80.6             8.6
# 20                                     61.8             6.0
# 21                                     46.6           -29.0
# 22                                     45.9           -14.7
# 23                                     45.3             4.5
# 24                                     50.3           -54.0
# 25                                     41.2            13.9
# 26                                     34.4           -12.5
# 27                                     55.4           -10.1
# 28                                     33.9             2.0
# 29                                     34.7             5.2
# 30                                     52.1           -27.0
# 31                                     28.5           -27.9
# 32                                     42.5            11.0
# 33                                     55.1           -14.1
# 34                                     59.6            29.7
# 35                                     27.1           -52.5
# 36                                     46.2            -9.9
# 37                                     51.4            29.0
# 38                                     64.8           -41.8
# 39                                     47.5           -25.7
# 40                                     45.5             6.2
#
#     Perceived social network support
# 0                                92.4
# 1                                89.8
# 2                                89.9
# 3                                91.9
# 4                                87.3
# 5                                80.4
# 6                                33.2
# 7                                93.7
# 8                                94.6
# 9                                93.6
# 10                               95.6
# 11                               87.4
# 12                               89.1
# 13                               84.1
# 14                               94.2
# 15                               97.7
# 16                               91.6
# 17                               93.5
# 18                               86.2
# 19                               87.7
# 20                               79.6
# 21                               91.9
# 22                               84.9
# 23                               88.7
# 24                               82.2
# 25                               92.7
# 26                               94.5
# 27                               93.9
# 28                               88.6
# 29                               87.3
# 30                               93.8
# 31                               93.9
# 32                               92.9
# 33                               93.5
# 34                               92.2
# 35                               80.2
# 36                               89.2
# 37                               89.1
# 38                                NaN
# 39                                NaN
# 40                                NaN

# %%
oecd_clean = oecd.dropna()
oecd_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 37
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   country                                       34 non-null     object
#  1   countrycode                                   34 non-null     object
#  2   Disposable income per capita                  34 non-null     object
#  3   Employment rate                               34 non-null     float64
#  4   Unemployment rate                             34 non-null     float64
#  5   Homicide rate                                 34 non-null     float64
#  6   Life expectancy                               34 non-null     float64
#  7   Population with at least secondary education  34 non-null     float64
#  8   Number of rooms per capita                    34 non-null     float64
#  9   Mortality rate                                34 non-null     float64
#  10  Voter turnout                                 34 non-null     float64
#  11  Households broadband access                   34 non-null     float64
#  12  Air quality (PM2.5)                           34 non-null     float64
#  13  Life satisfaction                             34 non-null     float64
#  14  Satisfaction with housing affordability       34 non-null     float64
#  15  Internet speed                                34 non-null     float64
#  16  Perceived social network support              34 non-null     float64
# dtypes: float64(14), object(3)
# memory usage: 4.8+ KB

# %%
oecd_clean = oecd_clean.drop(columns=['country' , 'countrycode'], axis =1)
oecd_clean
# Out:
#    Disposable income per capita  Employment rate  Unemployment rate  \
# 0                        39 872             76.3                4.1
# 1                        37 640             75.5                4.8
# 2                        35 487             62.8                5.8
# 3                        32 387             72.2                6.1
# 4                         8 261             62.9                8.7
# 6                        10 470             71.5                7.3
# 7                        26 092             75.1                2.3
# 8                        27 796             76.8                5.3
# 9                        17 711             74.4                7.9
# 10                       28 154             72.2                9.4
# 11                       30 656             65.0                7.6
# 12                       35 532             76.2                8.2
# 13                       20 931             70.9               12.9
# 14                       21 024             73.8                4.4
# 16                       29 853             75.1                4.5
# 17                       15 120             69.7                3.7
# 18                       31 920             61.9                7.5
# 19                       22 891             73.3                2.7
# 20                       25 303             62.0                2.7
# 21                       15 293             70.1                8.4
# 22                       17 929             72.5                6.8
# 23                       45 344             68.2                6.6
# 24                        8 358             63.9                2.7
# 25                       31 827             84.3                3.9
# 27                       32 368             77.4                3.7
# 28                       24 597             76.6                3.1
# 29                       26 467             72.6                6.2
# 30                       20 282             76.0                5.4
# 31                       27 250             73.1                3.7
# 32                       26 156             61.3               12.7
# 33                       30 943             77.4                8.5
# 34                       64 469             83.9                4.2
# 36                       33 222             78.5                3.6
# 37                       59 961             76.6                3.7
#
#     Homicide rate  Life expectancy  \
# 0             0.9             83.0
# 1             0.7             81.9
# 2             1.4             82.3
# 3             1.9             81.3
# 4             4.5             81.0
# 6            17.2             80.9
# 7             1.5             79.9
# 8             0.8             81.8
# 9             1.7             79.0
# 10            1.1             81.6
# 11            1.2             83.0
# 12            0.8             81.1
# 13            0.7             81.8
# 14            0.7             76.5
# 16            0.7             82.9
# 17            1.5             82.6
# 18            0.6             83.4
# 19            0.7             84.7
# 20            1.1             83.5
# 21            4.3             75.5
# 22            2.6             77.4
# 23            1.4             83.4
# 24           24.2             75.5
# 25            0.6             81.9
# 27            0.7             83.1
# 28            1.4             78.4
# 29            0.7             81.2
# 30            1.1             78.2
# 31            0.3             82.0
# 32            0.7             83.8
# 33            1.1             83.4
# 34            0.6             84.3
# 36            0.9             80.7
# 37            5.9             77.0
#
#     Population with at least secondary education  Number of rooms per capita  \
# 0                                           15.3                         2.3
# 1                                           13.8                         1.8
# 2                                           17.2                         2.1
# 3                                            6.9                         2.5
# 4                                           17.6                         1.3
# 6                                           58.6                         1.1
# 7                                            5.7                         1.5
# 8                                           16.4                         1.9
# 9                                           11.2                         1.6
# 10                                          11.1                         1.8
# 11                                          16.1                         1.8
# 12                                          16.2                         1.8
# 13                                          17.9                         1.3
# 14                                          11.9                         1.6
# 16                                          10.6                         2.0
# 17                                          12.4                         1.2
# 18                                          33.3                         1.5
# 19                                           5.4                         1.8
# 20                                           6.4                         1.6
# 21                                           9.1                         1.2
# 22                                           5.6                         1.6
# 23                                          17.6                         2.0
# 24                                          56.1                         1.5
# 25                                          19.2                         2.1
# 27                                          16.3                         2.3
# 28                                           5.2                         1.4
# 29                                          38.5                         2.0
# 30                                           6.1                         1.1
# 31                                          11.0                         1.6
# 32                                          35.1                         2.0
# 33                                          11.3                         1.8
# 34                                          13.8                         1.8
# 36                                          17.8                         2.0
# 37                                           9.7                         2.4
#
#     Mortality rate  Voter turnout  Households broadband access  \
# 0              3.0           89.8                         86.1
# 1              8.6           75.6                         91.0
# 2              8.6           90.7                         94.6
# 3              6.3           62.2                         93.3
# 4              9.9           46.7                         75.2
# 6              6.8           60.7                         80.1
# 7             10.2           65.4                         92.8
# 8              8.9           84.2                         92.5
# 9             10.3           63.5                         90.9
# 10             9.0           66.8                         95.5
# 11             8.0           77.8                         88.1
# 12            13.4           82.5                         88.8
# 13             9.1           53.7                         85.0
# 14            12.8           69.7                         94.8
# 16             8.2           59.7                         93.5
# 17             7.5           68.5                         74.3
# 18             7.9           63.9                         84.1
# 19             7.2           56.0                         71.7
# 20             6.8           66.2                         99.9
# 21            12.7           59.4                         94.3
# 22            11.4           52.2                         90.4
# 23             7.9           87.2                         97.4
# 24            11.8           61.0                         75.6
# 25             8.9           81.6                         98.6
# 27             8.1           77.1                         98.6
# 28            11.1           74.4                         95.0
# 29             8.4           59.8                         87.0
# 30            11.2           68.5                         90.5
# 31             8.7           53.6                         94.0
# 32             7.6           66.6                         96.8
# 33             7.9           87.1                        100.0
# 34             7.3           45.1                         98.1
# 36             9.2           60.3                         99.8
# 37            10.0           65.3                         86.4
#
#     Air quality (PM2.5)  Life satisfaction  \
# 0                   8.5                7.1
# 1                  11.1                7.0
# 2                  11.8                6.9
# 3                  12.7                7.0
# 4                  23.1                6.2
# 6                   8.7                6.8
# 7                  13.0                6.8
# 8                   9.2                7.6
# 9                   9.1                6.4
# 10                  7.1                7.8
# 11                 10.7                6.7
# 12                 11.6                6.9
# 13                 11.1                5.9
# 14                 12.5                6.1
# 16                  7.5                7.0
# 17                 20.6                7.3
# 18                 15.8                6.4
# 19                 17.2                6.0
# 20                 30.1                6.0
# 21                 10.4                6.2
# 22                  9.8                6.6
# 23                 10.5                7.2
# 24                 14.6                6.5
# 25                 12.1                7.4
# 27                  6.8                7.4
# 28                 13.5                6.3
# 29                 10.5                6.0
# 30                 10.9                6.3
# 31                 13.5                6.7
# 32                  9.7                6.4
# 33                  6.8                7.3
# 34                 12.5                7.3
# 36                  9.2                6.8
# 37                 12.7                6.8
#
#     Satisfaction with housing affordability  Internet speed  \
# 0                                      41.6           -44.8
# 1                                      59.9           -42.5
# 2                                      59.3           -16.3
# 3                                      38.8            22.4
# 4                                      28.7            49.4
# 6                                      55.0           -41.0
# 7                                      50.7           -41.9
# 8                                      71.3             7.6
# 9                                      62.8           -46.7
# 10                                     75.2           -13.1
# 11                                     47.9            46.3
# 12                                     55.8           -34.9
# 13                                     40.4           -56.2
# 14                                     44.8             3.9
# 16                                     42.5            -9.2
# 17                                     29.7            27.7
# 18                                     56.3            -9.0
# 19                                     80.6             8.6
# 20                                     61.8             6.0
# 21                                     46.6           -29.0
# 22                                     45.9           -14.7
# 23                                     45.3             4.5
# 24                                     50.3           -54.0
# 25                                     41.2            13.9
# 27                                     55.4           -10.1
# 28                                     33.9             2.0
# 29                                     34.7             5.2
# 30                                     52.1           -27.0
# 31                                     28.5           -27.9
# 32                                     42.5            11.0
# 33                                     55.1           -14.1
# 34                                     59.6            29.7
# 36                                     46.2            -9.9
# 37                                     51.4            29.0
#
#     Perceived social network support
# 0                                92.4
# 1                                89.8
# 2                                89.9
# 3                                91.9
# 4                                87.3
# 6                                33.2
# 7                                93.7
# 8                                94.6
# 9                                93.6
# 10                               95.6
# 11                               87.4
# 12                               89.1
# 13                               84.1
# 14                               94.2
# 16                               91.6
# 17                               93.5
# 18                               86.2
# 19                               87.7
# 20                               79.6
# 21                               91.9
# 22                               84.9
# 23                               88.7
# 24                               82.2
# 25                               92.7
# 27                               93.9
# 28                               88.6
# 29                               87.3
# 30                               93.8
# 31                               93.9
# 32                               92.9
# 33                               93.5
# 34                               92.2
# 36                               89.2
# 37                               89.1

# %%
oecd_clean['Disposable income per capita'] = oecd_clean['Disposable income per capita'].str.replace(' ', '').astype(int)

# %%
oecd_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 37
# Data columns (total 15 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Disposable income per capita                  34 non-null     int64
#  1   Employment rate                               34 non-null     float64
#  2   Unemployment rate                             34 non-null     float64
#  3   Homicide rate                                 34 non-null     float64
#  4   Life expectancy                               34 non-null     float64
#  5   Population with at least secondary education  34 non-null     float64
#  6   Number of rooms per capita                    34 non-null     float64
#  7   Mortality rate                                34 non-null     float64
#  8   Voter turnout                                 34 non-null     float64
#  9   Households broadband access                   34 non-null     float64
#  10  Air quality (PM2.5)                           34 non-null     float64
#  11  Life satisfaction                             34 non-null     float64
#  12  Satisfaction with housing affordability       34 non-null     float64
#  13  Internet speed                                34 non-null     float64
#  14  Perceived social network support              34 non-null     float64
# dtypes: float64(14), int64(1)
# memory usage: 4.2 KB

# %% [markdown]
# ## K-Means

# %% [markdown]
# Perform [K-Means](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) on the provided countries data set. You may include the full set of variables, or a subset of variables based on any of your initial data cleaning.
#
# Set the number of clusters to `4` and use the `n_init=20` parameter to evaluate 20 different random initializations of the model.
#
# After fitting the model, evaluate its classification on the full data set. You can extract these labels in two ways.
#
# 1. You can call the `.labels_` attribute of your fit model object
# 2. You can apply the `.predict()` method from your fit model object to the underlying data
#
# Examine how the countries have been grouped among these clusters and comment on any patterns.
#
#
# Note: Ensure that you do not try to pass the `ccode` or `country` variables to your fitting process as these variables are non-numeric.

# %%
oecd_clean_knn = KMeans(n_clusters = 4, random_state=422,
                # Number of times to randomly initialise and run the algorithm
                n_init=10
                )

# Fitting it to our data set
oecd_clean_knn = oecd_clean_knn.fit(oecd_clean)

oecd_clean_knn
# Out:
# c:\Users\Muhammad-\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, n_init=10, random_state=422)

# %% [markdown]
# ## Different Values of K with the Elbow Method

# %% [markdown]
# Use the elbow method to identify an optimal number of clusters. To do this:
#
# 1. Fit a range of models with K-Means, using different values of `k` in each case. Use the `n_init=20` parameter to run the code for 20 different starting points. Consider a range of values of `k` from `2` to `20`
# 2. For each fitted model, save the `inertia` score from this model, which is a measure of the within cluster variance. This score can be accessed from the fit model with the `.inertia_` attribute
# 3. Create a plot of these inertia values against the number of identified clusters.
#
# Evaluate your plot from Step 3 above and comment on the shape and any patterns. Based on this plot, what seems to be an appropriate number of clusters?
#
# Fit a new model with this number of clusters and compare the groups to those identified above with `k=4`. How do the clusters compare in these two cases?

# %% [markdown]
# ## Different Values of K with the Silhouette Score

# %% [markdown]
# An alternative way to score the performance of a clustering algorithm is via the [Silhouette Score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html). A function to calculate this can be loaded with the following code:
#
# ```python
# from sklearn.metrics import silhouette_score
# ```
#
# The silhouette score is a measure of how _similar_ observations are, and thus higher values indicate more similar values, and potentially better clusters. Replicate your analysis from the elbow method above, this time trying a range of clusters from k=2 to k=20. For each model save the silhouette score. Which value of k produces the highest silhouette score?
#
# Fit a new K-Means model with this value of k to your data where you have dropped measures of population. Are the clusters in this model materially different than your earlier clusters?
#
# Note, the silhouette score takes as arguments the underlying data and the assigned labels from the model. The labels from the model can be extracted with the `.labels_` attribute.

# %% [markdown]
# ## Clustering with HAC

# %% [markdown]
# Implement [AgglomerativeClustering](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html) on this data. You can also review the user guide for this function [here](https://scikit-learn.org/stable/modules/clustering.html#hierarchical-clustering).
#
# To do this, load the function with the following code:
#
# ```python
# from sklearn.cluster import AgglomerativeClustering
# ```
#
# Use the following hyperparameters to fit the model:
#
# 1. Set `distance_threshold=None` - this will allow the algorithm to fully merge all clusters
# 2. Set `n_clusters=4` - this will create four distinct clusters
# 3. Set `linkage='complete'` - this specifies the metric used to calculate the distance between clusters
#
# How do the clusters identified here compare to those identified by K-Means?

# %% [markdown]
# ## Building a Dendrogram - OPTIONAL

# %% [markdown]
# Refit your hierarchical model with the following parameters (if you choose to do so in sklearn).
#
# 1. Set `distance_threshold=0`
# 2. Set `n_clusters=None`
# 3. Set `linkage='ward'`
#
# Build and display a dendrogram for this cluster analysis. Aim to include the country `ccode` variable as the label at the bottom of your dendrogram. There are several possible ways to do this, as sklearn does not have the easiest functionality to work with for creating a dendrogram. You may find it helpful to search on stack overflow. There are also further examples on.
#
# 1. [Plotly](https://plotly.com/python/dendrogram/)
# 2. [SciPy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.dendrogram.html)
#
# Note, if using these alternative sources, they may fit the models with packages besides `sklearn`.
#
# Looking at the dendrogram, does there appear to be any large jumps in the vertical distance where the distance between newly merged clusters quickly increases?
#
# Note: I expect the process for generating this plot will require looking at examples outside of those presented in class. Your aim should be to use keyword searches to find useful code which you can modify to your purposes.
